# %% [markdown]
# <img src="images/pilot.png" alt="Pilot" width="30%"/>
#
# Todos:
#
# 0. printing stuff
# 1. variables (`str`, `int`, `float`, `list`)
# 2. operations (adding, etc)
# 3. lists
# 4. loops
# 5. functions
# 6. classes

# %% [markdown]
# (bonus)
#
# 7. writing sane code (`typing`)
# 8. writing safe code (`assert`)
#
# These would help you avoid disasters when vibe-coding
